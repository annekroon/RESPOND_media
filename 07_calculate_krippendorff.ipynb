# %%
import os
import json
import pandas as pd
import numpy as np
import krippendorff
from itertools import combinations
import matplotlib.pyplot as plt
import seaborn as sns

# === CONFIG ===
SESSION_FOLDER = os.path.expanduser("~/webdav/ASCOR-FMG-5580-RESPOND-news-data (Projectfolder)/sessions/")
LLM_FILE = os.path.expanduser("~/webdav/ASCOR-FMG-5580-RESPOND-news-data (Projectfolder)/annotations/coding_frames/ICR/ICR_test1/news_sample_with_7_frames_intercoder.csv")

# Frame labels used in analysis
FRAME_LABELS = [
    "Foreign influence threat_present",
    "Systemic institutional corruption_present",
    "Elite collusion_present",
    "Politicized investigations_present",
    "Authoritarian reformism_present",
    "Judicial and institutional accountability failures_present",
    "Mobilizing anti-corruption_present"
]

# Mapping to CSV columns like 'frame_1_name'
FRAME_NAME_TO_COLUMN = {
    "Foreign influence threat_present": "frame_1_name",
    "Systemic institutional corruption_present": "frame_2_name",
    "Elite collusion_present": "frame_3_name",
    "Politicized investigations_present": "frame_4_name",
    "Authoritarian reformism_present": "frame_5_name",
    "Judicial and institutional accountability failures_present": "frame_6_name",
    "Mobilizing anti-corruption_present": "frame_7_name"
}

# === HELPERS ===
def encode_label(val):
    return 1 if val == "Present" else 0 if val == "Not Present" else None

def load_all_annotations():
    data = []
    for filename in os.listdir(SESSION_FOLDER):
        if filename.endswith("_session.json"):
            user_id = filename.replace("_session.json", "")
            path = os.path.join(SESSION_FOLDER, filename)
            with open(path, "r", encoding="utf-8") as f:
                session_data = json.load(f)
                annotations = session_data.get("annotations", [])
                for ann in annotations:
                    ann["user_id"] = user_id
                    data.append(ann)
    df = pd.DataFrame(data)

    # Only consider selected annotators
    allowed_annotators = ["Assia", "Alexander", "Elisa", "Luigia", "Yara"]
    df = df[df["user_id"].isin(allowed_annotators)]

    # ✅ Only keep annotators who coded all 15 articles
    annotator_counts = df.groupby("user_id")["uri"].nunique()
    complete_annotators = annotator_counts[annotator_counts == 15].index.tolist()
    df = df[df["user_id"].isin(complete_annotators)]

    print(f"✅ Annotators who coded all 15 articles: {complete_annotators}")
    return df


def prepare_matrix(df, frame_label):
    df_sub = df[["user_id", "uri", frame_label]].copy()
    df_sub[frame_label] = df_sub[frame_label].map(encode_label)
    pivot = df_sub.pivot(index="uri", columns="user_id", values=frame_label)
    return pivot

def safe_krippendorff_alpha(data, level='nominal'):
    unique_vals = np.unique(data[~np.isnan(data)])
    if len(unique_vals) < 2:
        return 1.0
    try:
        alpha = krippendorff.alpha(reliability_data=data, level_of_measurement=level)
        return alpha if not isinstance(alpha, (np.ndarray, list)) else np.nan
    except Exception as e:
        print(f"⚠️ Error computing alpha: {e}")
        return np.nan

def pairwise_krippendorff(matrix, coders):
    pairwise_results = {}
    for coder1, coder2 in combinations(coders, 2):
        pair_data = matrix[[coder1, coder2]].dropna()
        n_rows = pair_data.shape[0]
        alpha = safe_krippendorff_alpha(pair_data.to_numpy().T) if n_rows > 0 else np.nan
        if n_rows == 0:
            print(f"⚠️ No overlapping articles for {coder1} vs {coder2}")
        pairwise_results[(coder1, coder2)] = (alpha, n_rows)
    return pairwise_results

# === MAIN FUNCTION ===
def compute_fine_grained_reliability():
    df = load_all_annotations()
    coders = df["user_id"].unique()

    # Load LLM annotations
    llm_df = pd.read_csv(LLM_FILE)
    llm_df["user_id"] = "LLM"

    frame_results = []

    for frame_label in FRAME_LABELS:
        print(f"\n=== Frame: {frame_label} ===")

        # Prepare human matrix
        matrix = prepare_matrix(df, frame_label)

        # Get corresponding column in LLM file
        llm_column = FRAME_NAME_TO_COLUMN[frame_label]
        llm_frame_data = llm_df[["uri", llm_column]].copy()
        llm_frame_data[llm_column] = llm_frame_data[llm_column].apply(
            lambda x: "Present" if isinstance(x, str) and x.strip() != "" else "Not Present"
        )
        llm_frame_data[llm_column] = llm_frame_data[llm_column].map(encode_label)
        llm_frame_data = llm_frame_data.set_index("uri").rename(columns={llm_column: "LLM"})

        # Merge
        combined_matrix = matrix.join(llm_frame_data, how="outer")
        coders_with_data = [c for c in combined_matrix.columns if combined_matrix[c].notna().any()]
        #coders_with_data = [c for c in combined_matrix.columns if c != "LLM" and combined_matrix[c].notna().any()]

        
        if len(coders_with_data) < 2:
            print("Not enough coders with data to compute reliability.")
            frame_results.append({
                "frame": frame_label,
                "overall_alpha": np.nan,
                "avg_pairwise_alpha": np.nan,
                "num_disagreements": 0,
                "num_agreements": 0,
                "num_articles_coded_by_all": 0
            })
            continue

        # Pairwise alphas
        pairwise_alphas = pairwise_krippendorff(combined_matrix, coders_with_data)
        print("Pairwise Krippendorff's alpha (alpha, number of articles):")
        for (c1, c2), (alpha, n_rows) in sorted(pairwise_alphas.items()):
            print(f"  {c1} vs {c2}: α = {alpha:.3f}, articles = {n_rows}" if not np.isnan(alpha)
                  else f"  {c1} vs {c2}: α = N/A, articles = {n_rows}")

        # Per coder average
        coder_scores = {coder: [] for coder in coders_with_data}
        for (c1, c2), (alpha, _) in pairwise_alphas.items():
            if not np.isnan(alpha):
                coder_scores[c1].append(alpha)
                coder_scores[c2].append(alpha)

        print("\nAverage pairwise alpha per coder:")
        for coder, scores in coder_scores.items():
            print(f"  {coder}: {np.mean(scores):.3f}" if scores else f"  {coder}: No scores")

        # Overall alpha
        complete_data = combined_matrix.dropna(how='any')
        num_articles_coded_by_all = complete_data.shape[0]
        overall_alpha = safe_krippendorff_alpha(complete_data.to_numpy().T) if num_articles_coded_by_all > 0 else np.nan
        print(f"\n✅ Overall Krippendorff's alpha: α = {overall_alpha:.3f}" if not np.isnan(overall_alpha)
              else "\n⚠️ No article coded by all coders — can't compute overall alpha.")

        # Agreement/disagreement
        disagreement_count = complete_data.apply(lambda row: len(set(row)), axis=1)
        num_disagreements = (disagreement_count > 1).sum()
        num_agreements = (disagreement_count == 1).sum()

        print(f"{frame_label}: {num_disagreements} articles with coder disagreement")
        print(f"{frame_label}: {num_agreements} articles with coder agreement")
        print(f"{frame_label}: {num_articles_coded_by_all} articles coded by all coders")

        frame_results.append({
            "frame": frame_label,
            "overall_alpha": overall_alpha,
            "avg_pairwise_alpha": np.mean([v[0] for v in pairwise_alphas.values() if not np.isnan(v[0])]) if pairwise_alphas else np.nan,
            "num_disagreements": num_disagreements,
            "num_agreements": num_agreements,
            "num_articles_coded_by_all": num_articles_coded_by_all
        })

    results_df = pd.DataFrame(frame_results)
    results_df.to_excel("reliability_results_with_llm.xlsx", index=False)
    print("\n✅ Results saved to 'reliability_results_with_llm.xlsx'")
    return results_df

# === PLOT FUNCTION ===
def plot_results(results_df):
    sns.set(style="whitegrid")
    plt.figure(figsize=(12, 6))
    results_df_sorted = results_df.sort_values("overall_alpha", ascending=False)

    ax = sns.barplot(data=results_df_sorted, x="overall_alpha", y="frame", palette="viridis")
    ax.set_title("Overall Krippendorff's Alpha per Frame (Including LLM)", fontsize=16)
    ax.set_xlabel("Overall α", fontsize=12)
    ax.set_ylabel("Frame", fontsize=12)
    ax.set_xlim(0, 1)

    for i, val in enumerate(results_df_sorted["overall_alpha"]):
        if not np.isnan(val):
            ax.text(val + 0.02, i, f"{val:.2f}", va='center')

    plt.tight_layout()
    plt.show()

# === RUN ===
if __name__ == "__main__":
    results_df = compute_fine_grained_reliability()
    print("\n=== Summary DataFrame ===")
    print(results_df)
    plot_results(results_df)
# Out:
# ✅ Annotators who coded all 15 articles: ['Alexander', 'Assia', 'Elisa', 'Luigia', 'Yara']
#
# === Frame: Foreign influence threat_present ===
# Pairwise Krippendorff's alpha (alpha, number of articles):
#   Alexander vs Assia: α = 0.000, articles = 15
#   Alexander vs Elisa: α = -0.036, articles = 15
#   Alexander vs LLM: α = -0.074, articles = 15
#   Alexander vs Luigia: α = 1.000, articles = 15
#   Alexander vs Yara: α = 0.000, articles = 15
#   Assia vs Elisa: α = 0.000, articles = 15
#   Assia vs LLM: α = -0.036, articles = 15
#   Assia vs Luigia: α = 0.000, articles = 15
#   Assia vs Yara: α = 1.000, articles = 15
#   Elisa vs LLM: α = 0.642, articles = 15
#   Elisa vs Luigia: α = -0.036, articles = 15
#   Elisa vs Yara: α = 0.000, articles = 15
#   Luigia vs LLM: α = -0.074, articles = 15
#   Luigia vs Yara: α = 0.000, articles = 15
#   Yara vs LLM: α = -0.036, articles = 15
#
# Average pairwise alpha per coder:
#   Alexander: 0.178
#   Assia: 0.193
#   Elisa: 0.114
#   Luigia: 0.178
#   Yara: 0.193
#   LLM: 0.084
#
# ✅ Overall Krippendorff's alpha: α = 0.120
# Foreign influence threat_present: 3 articles with coder disagreement
# Foreign influence threat_present: 12 articles with coder agreement
# Foreign influence threat_present: 15 articles coded by all coders
#
# === Frame: Systemic institutional corruption_present ===
# Pairwise Krippendorff's alpha (alpha, number of articles):
#   Alexander vs Assia: α = 0.584, articles = 15
#   Alexander vs Elisa: α = 0.341, articles = 15
#   Alexander vs LLM: α = 0.420, articles = 15
#   Alexander vs Luigia: α = 0.847, articles = 15
#   Alexander vs Yara: α = 0.460, articles = 15
#   Assia vs Elisa: α = 0.233, articles = 15
#   Assia vs LLM: α = 0.584, articles = 15
#   Assia vs Luigia: α = 0.420, articles = 15
#   Assia vs Yara: α = 0.341, articles = 15
#   Elisa vs LLM: α = 0.341, articles = 15
#   Elisa vs Luigia: α = 0.460, articles = 15
#   Elisa vs Yara: α = 0.304, articles = 15
#   Luigia vs LLM: α = 0.233, articles = 15
#   Luigia vs Yara: α = 0.597, articles = 15
#   Yara vs LLM: α = 0.460, articles = 15
#
# Average pairwise alpha per coder:
#   Alexander: 0.530
#   Assia: 0.432
#   Elisa: 0.336
#   Luigia: 0.511
#   Yara: 0.432
#   LLM: 0.407
#
# ✅ Overall Krippendorff's alpha: α = 0.441
# Systemic institutional corruption_present: 7 articles with coder disagreement
# Systemic institutional corruption_present: 8 articles with coder agreement
# Systemic institutional corruption_present: 15 articles coded by all coders
#
# === Frame: Elite collusion_present ===
# Pairwise Krippendorff's alpha (alpha, number of articles):
#   Alexander vs Assia: α = 0.463, articles = 15
#   Alexander vs Elisa: α = 0.606, articles = 15
#   Alexander vs LLM: α = 0.606, articles = 15
#   Alexander vs Luigia: α = 0.233, articles = 15
#   Alexander vs Yara: α = 0.344, articles = 15
#   Assia vs Elisa: α = 0.306, articles = 15
#   Assia vs LLM: α = 0.861, articles = 15
#   Assia vs Luigia: α = 0.460, articles = 15
#   Assia vs Yara: α = 0.306, articles = 15
#   Elisa vs LLM: α = 0.463, articles = 15
#   Elisa vs Luigia: α = 0.341, articles = 15
#   Elisa vs Yara: α = -0.074, articles = 15
#   Luigia vs LLM: α = 0.341, articles = 15
#   Luigia vs Yara: α = 0.011, articles = 15
#   Yara vs LLM: α = 0.194, articles = 15
#
# Average pairwise alpha per coder:
#   Alexander: 0.450
#   Assia: 0.479
#   Elisa: 0.328
#   Luigia: 0.277
#   Yara: 0.156
#   LLM: 0.493
#
# ✅ Overall Krippendorff's alpha: α = 0.367
# Elite collusion_present: 10 articles with coder disagreement
# Elite collusion_present: 5 articles with coder agreement
# Elite collusion_present: 15 articles coded by all coders
#
# === Frame: Politicized investigations_present ===
# Pairwise Krippendorff's alpha (alpha, number of articles):
#   Alexander vs Assia: α = 0.670, articles = 15
#   Alexander vs Elisa: α = 0.820, articles = 15
#   Alexander vs LLM: α = 0.460, articles = 15
#   Alexander vs Luigia: α = 0.442, articles = 15
#   Alexander vs Yara: α = 1.000, articles = 15
#   Assia vs Elisa: α = 0.540, articles = 15
#   Assia vs LLM: α = 0.540, articles = 15
#   Assia vs Luigia: α = 0.194, articles = 15
#   Assia vs Yara: α = 0.670, articles = 15
#   Elisa vs LLM: α = 0.341, articles = 15
#   Elisa vs Luigia: α = 0.304, articles = 15
#   Elisa vs Yara: α = 0.820, articles = 15
#   Luigia vs LLM: α = 0.304, articles = 15
#   Luigia vs Yara: α = 0.442, articles = 15
#   Yara vs LLM: α = 0.460, articles = 15
#
# Average pairwise alpha per coder:
#   Alexander: 0.678
#   Assia: 0.523
#   Elisa: 0.565
#   Luigia: 0.337
#   Yara: 0.678
#   LLM: 0.421
#
# ✅ Overall Krippendorff's alpha: α = 0.542
# Politicized investigations_present: 6 articles with coder disagreement
# Politicized investigations_present: 9 articles with coder agreement
# Politicized investigations_present: 15 articles coded by all coders
#
# === Frame: Authoritarian reformism_present ===
# Pairwise Krippendorff's alpha (alpha, number of articles):
#   Alexander vs Assia: α = -0.036, articles = 15
#   Alexander vs Elisa: α = -0.036, articles = 15
#   Alexander vs LLM: α = 0.000, articles = 15
#   Alexander vs Luigia: α = -0.074, articles = 15
#   Alexander vs Yara: α = -0.036, articles = 15
#   Assia vs Elisa: α = -0.115, articles = 15
#   Assia vs LLM: α = -0.074, articles = 15
#   Assia vs Luigia: α = 0.304, articles = 15
#   Assia vs Yara: α = 0.442, articles = 15
#   Elisa vs LLM: α = -0.074, articles = 15
#   Elisa vs Luigia: α = 0.768, articles = 15
#   Elisa vs Yara: α = 0.442, articles = 15
#   Luigia vs LLM: α = -0.115, articles = 15
#   Luigia vs Yara: α = 0.768, articles = 15
#   Yara vs LLM: α = -0.074, articles = 15
#
# Average pairwise alpha per coder:
#   Alexander: -0.036
#   Assia: 0.104
#   Elisa: 0.197
#   Luigia: 0.330
#   Yara: 0.309
#   LLM: -0.068
#
# ✅ Overall Krippendorff's alpha: α = 0.199
# Authoritarian reformism_present: 5 articles with coder disagreement
# Authoritarian reformism_present: 10 articles with coder agreement
# Authoritarian reformism_present: 15 articles coded by all coders
#
# === Frame: Judicial and institutional accountability failures_present ===
# Pairwise Krippendorff's alpha (alpha, number of articles):
#   Alexander vs Assia: α = 0.233, articles = 15
#   Alexander vs Elisa: α = 0.861, articles = 15
#   Alexander vs LLM: α = 0.540, articles = 15
#   Alexander vs Luigia: α = 0.344, articles = 15
#   Alexander vs Yara: α = 0.463, articles = 15
#   Assia vs Elisa: α = 0.130, articles = 15
#   Assia vs LLM: α = 0.341, articles = 15
#   Assia vs Luigia: α = 0.194, articles = 15
#   Assia vs Yara: α = 0.584, articles = 15
#   Elisa vs LLM: α = 0.420, articles = 15
#   Elisa vs Luigia: α = 0.223, articles = 15
#   Elisa vs Yara: α = 0.344, articles = 15
#   Luigia vs LLM: α = 0.194, articles = 15
#   Luigia vs Yara: α = 0.356, articles = 15
#   Yara vs LLM: α = 0.029, articles = 15
#
# Average pairwise alpha per coder:
#   Alexander: 0.488
#   Assia: 0.296
#   Elisa: 0.396
#   Luigia: 0.262
#   Yara: 0.355
#   LLM: 0.305
#
# ✅ Overall Krippendorff's alpha: α = 0.346
# Judicial and institutional accountability failures_present: 10 articles with coder disagreement
# Judicial and institutional accountability failures_present: 5 articles with coder agreement
# Judicial and institutional accountability failures_present: 15 articles coded by all coders
#
# === Frame: Mobilizing anti-corruption_present ===
# Pairwise Krippendorff's alpha (alpha, number of articles):
#   Alexander vs Assia: α = 0.597, articles = 15
#   Alexander vs Elisa: α = 0.460, articles = 15
#   Alexander vs LLM: α = 0.768, articles = 15
#   Alexander vs Luigia: α = 0.460, articles = 15
#   Alexander vs Yara: α = 0.768, articles = 15
#   Assia vs Elisa: α = 0.847, articles = 15
#   Assia vs LLM: α = 0.820, articles = 15
#   Assia vs Luigia: α = 0.847, articles = 15
#   Assia vs Yara: α = 0.820, articles = 15
#   Elisa vs LLM: α = 0.670, articles = 15
#   Elisa vs Luigia: α = 0.710, articles = 15
#   Elisa vs Yara: α = 0.670, articles = 15
#   Luigia vs LLM: α = 0.670, articles = 15
#   Luigia vs Yara: α = 0.670, articles = 15
#   Yara vs LLM: α = 0.597, articles = 15
#
# Average pairwise alpha per coder:
#   Alexander: 0.610
#   Assia: 0.786
#   Elisa: 0.671
#   Luigia: 0.671
#   Yara: 0.705
#   LLM: 0.705
#
# ✅ Overall Krippendorff's alpha: α = 0.691
# Mobilizing anti-corruption_present: 4 articles with coder disagreement
# Mobilizing anti-corruption_present: 11 articles with coder agreement
# Mobilizing anti-corruption_present: 15 articles coded by all coders
#
# ✅ Results saved to 'reliability_results_with_llm.xlsx'
#
# === Summary DataFrame ===
#                                                frame  overall_alpha  \
# 0                   Foreign influence threat_present       0.120471
# 1          Systemic institutional corruption_present       0.441354
# 2                            Elite collusion_present       0.367026
# 3                 Politicized investigations_present       0.542286
# 4                    Authoritarian reformism_present       0.199000
# 5  Judicial and institutional accountability fail...       0.345588
# 6                 Mobilizing anti-corruption_present       0.690642
#
#    avg_pairwise_alpha  num_disagreements  num_agreements  \
# 0            0.156731                  3              12
# 1            0.441498                  7               8
# 2            0.364144                 10               5
# 3            0.533817                  6               9
# 4            0.139360                  5              10
# 5            0.350366                 10               5
# 6            0.691626                  4              11
#
#    num_articles_coded_by_all
# 0                         15
# 1                         15
# 2                         15
# 3                         15
# 4                         15
# 5                         15
# 6                         15
# /tmp/ipykernel_1787873/2135652840.py:193: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=results_df_sorted, x="overall_alpha", y="frame", palette="viridis")

# %%
results_df
# Out:
#                                                frame  overall_alpha  \
# 0                   Foreign influence threat_present       0.120471
# 1          Systemic institutional corruption_present       0.441354
# 2                            Elite collusion_present       0.367026
# 3                 Politicized investigations_present       0.542286
# 4                    Authoritarian reformism_present       0.199000
# 5  Judicial and institutional accountability fail...       0.345588
# 6                 Mobilizing anti-corruption_present       0.690642
#
#    avg_pairwise_alpha  num_disagreements  num_agreements  \
# 0            0.156731                  3              12
# 1            0.441498                  7               8
# 2            0.364144                 10               5
# 3            0.533817                  6               9
# 4            0.139360                  5              10
# 5            0.350366                 10               5
# 6            0.691626                  4              11
#
#    num_articles_coded_by_all
# 0                         15
# 1                         15
# 2                         15
# 3                         15
# 4                         15
# 5                         15
# 6                         15

# %%
from openpyxl import Workbook
from openpyxl.styles import PatternFill
from openpyxl.utils.dataframe import dataframe_to_rows

def export_agreement_with_yara_and_text(df, llm_df, output_path="agreement_with_yara_and_text.xlsx"):
    wb = Workbook()
    wb.remove(wb.active)  # Remove default sheet

    # Merge translated text
    translated_texts = llm_df.set_index("uri")["translated_text"]

    for frame_label in FRAME_LABELS:
        frame_col = frame_label
        llm_col = FRAME_NAME_TO_COLUMN[frame_label]

        # Prepare human annotations
        matrix = prepare_matrix(df, frame_label)

        # Add LLM
        llm_frame_data = llm_df[["uri", llm_col]].copy()
        llm_frame_data[llm_col] = llm_frame_data[llm_col].apply(lambda x: "Present" if isinstance(x, str) and x.strip() != "" else "Not Present")
        llm_frame_data[llm_col] = llm_frame_data[llm_col].map(encode_label)
        llm_frame_data = llm_frame_data.set_index("uri").rename(columns={llm_col: "LLM"})

        # Join LLM + Human annotations
        combined_matrix = matrix.join(llm_frame_data)

        # Add Yara if missing
        if "Yara" not in combined_matrix.columns:
            print(f"⚠️ Skipping {frame_label} — Yara missing")
            continue

        # Add translated text
        combined_matrix["translated_text"] = translated_texts

        # Compute agreement with Yara
        yara_vector = combined_matrix["Yara"]
        agreement_df = combined_matrix.drop(columns=["Yara", "translated_text"]).copy()
        for col in agreement_df.columns:
            agreement_df[col] = agreement_df[col] == yara_vector

        # Create worksheet
        sheet_title = frame_label[:31]
        ws = wb.create_sheet(title=sheet_title)

        # Header
        ws.append(["URI", "Translated Text"] + list(agreement_df.columns) + ["Yara"])

        green_fill = PatternFill(start_color="C6EFCE", end_color="C6EFCE", fill_type="solid")  # Green
        red_fill = PatternFill(start_color="FFC7CE", end_color="FFC7CE", fill_type="solid")    # Red

        for uri in combined_matrix.index:
            text = combined_matrix.loc[uri, "translated_text"]
            row = [uri, text]

            # Add coder values
            for col in agreement_df.columns:
                val = combined_matrix.loc[uri, col]
                row.append(val)

            # Add Yara last
            yara_val = combined_matrix.loc[uri, "Yara"]
            row.append(yara_val)
            ws.append(row)

        # Color cells based on agreement
        for i, uri in enumerate(combined_matrix.index, start=2):  # skip header
            for j, col in enumerate(agreement_df.columns, start=3):  # 1=uri, 2=text
                cell = ws.cell(row=i, column=j)
                agrees = agreement_df.loc[uri, col]
                val = combined_matrix.loc[uri, col]
                yara_val = combined_matrix.loc[uri, "Yara"]

                if pd.isna(val) or pd.isna(yara_val):
                    continue
                if agrees:
                    cell.fill = green_fill
                else:
                    cell.fill = red_fill

    wb.save(output_path)
    print(f"✅ Agreement Excel saved to: {output_path}")

# %%
if __name__ == "__main__":
    results_df = compute_fine_grained_reliability()

    # Load input again
    df = load_all_annotations()
    llm_df = pd.read_csv(LLM_FILE)
    llm_df["user_id"] = "LLM"

    export_agreement_with_yara_and_text(df, llm_df, output_path=os.path.expanduser("~/webdav/ASCOR-FMG-5580-RESPOND-news-data (Projectfolder)/annotations/coding_frames/ICR/agreement_with_yara_and_text.xlsx"))
# Out:
# ⚠️ Skipping unknown annotator: Anne
# ⚠️ Skipping unknown annotator: anne
# ⚠️ Skipping unknown annotator: code1
# ⚠️ Skipping unknown annotator: coder1
# ⚠️ Skipping unknown annotator: frozen
# ⚠️ Skipping unknown annotator: simone
# ✅ Annotators who coded all 15 articles: ['Alexander', 'Assia', 'Elisa', 'Luigia', 'Yara']
#
# === Frame: Foreign influence threat_present ===
# Coder A      Coder B      Alpha    Shared Articles
# ---------------------------------------------
# Alexander    Assia        0.000    15
# Alexander    Elisa        -0.036   15
# Alexander    LLM          0.000    15
# Alexander    Luigia       1.000    15
# Alexander    Yara         0.000    15
# Assia        Elisa        0.000    15
# Assia        LLM          1.000    15
# Assia        Luigia       0.000    15
# Assia        Yara         1.000    15
# Elisa        LLM          0.000    15
# Elisa        Luigia       -0.036   15
# Elisa        Yara         0.000    15
# Luigia       LLM          0.000    15
# Luigia       Yara         0.000    15
# Yara         LLM          1.000    15
#
# Average pairwise alpha per coder:
#   Alexander: 0.193
#   Assia: 0.400
#   Elisa: -0.014
#   Luigia: 0.193
#   Yara: 0.400
#   LLM: 0.400
#
# ✅ Overall Krippendorff's alpha: α = 0.113
# Foreign influence threat_present: 2 articles with coder disagreement
# Foreign influence threat_present: 13 articles with coder agreement
# Foreign influence threat_present: 15 articles coded by all coders
#
# === Frame: Systemic institutional corruption_present ===
# Coder A      Coder B      Alpha    Shared Articles
# ---------------------------------------------
# Alexander    Assia        0.584    15
# Alexander    Elisa        0.341    15
# Alexander    LLM          0.540    15
# Alexander    Luigia       0.847    15
# Alexander    Yara         0.670    15
# Assia        Elisa        0.233    15
# Assia        LLM          0.420    15
# Assia        Luigia       0.420    15
# Assia        Yara         0.540    15
# Elisa        LLM          0.460    15
# Elisa        Luigia       0.460    15
# Elisa        Yara         0.597    15
# Luigia       LLM          0.341    15
# Luigia       Yara         0.820    15
# Yara         LLM          0.460    15
#
# Average pairwise alpha per coder:
#   Alexander: 0.596
#   Assia: 0.439
#   Elisa: 0.418
#   Luigia: 0.577
#   Yara: 0.617
#   LLM: 0.444
#
# ✅ Overall Krippendorff's alpha: α = 0.507
# Systemic institutional corruption_present: 7 articles with coder disagreement
# Systemic institutional corruption_present: 8 articles with coder agreement
# Systemic institutional corruption_present: 15 articles coded by all coders
#
# === Frame: Elite collusion_present ===
# Coder A      Coder B      Alpha    Shared Articles
# ---------------------------------------------
# Alexander    Assia        0.463    15
# Alexander    Elisa        0.606    15
# Alexander    LLM          0.344    15
# Alexander    Luigia       0.233    15
# Alexander    Yara         0.482    15
# Assia        Elisa        0.306    15
# Assia        LLM          0.356    15
# Assia        Luigia       0.460    15
# Assia        Yara         0.194    15
# Elisa        LLM          -0.036   15
# Elisa        Luigia       0.341    15
# Elisa        Yara         0.081    15
# Luigia       LLM          -0.074   15
# Luigia       Yara         -0.074   15
# Yara         LLM          0.606    15
#
# Average pairwise alpha per coder:
#   Alexander: 0.426
#   Assia: 0.356
#   Elisa: 0.260
#   Luigia: 0.177
#   Yara: 0.258
#   LLM: 0.239
#
# ✅ Overall Krippendorff's alpha: α = 0.301
# Elite collusion_present: 11 articles with coder disagreement
# Elite collusion_present: 4 articles with coder agreement
# Elite collusion_present: 15 articles coded by all coders
#
# === Frame: Politicized investigations_present ===
# Coder A      Coder B      Alpha    Shared Articles
# ---------------------------------------------
# Alexander    Assia        0.670    15
# Alexander    Elisa        0.820    15
# Alexander    LLM          0.597    15
# Alexander    Luigia       0.442    15
# Alexander    Yara         1.000    15
# Assia        Elisa        0.540    15
# Assia        LLM          0.341    15
# Assia        Luigia       0.194    15
# Assia        Yara         0.670    15
# Elisa        LLM          0.820    15
# Elisa        Luigia       0.304    15
# Elisa        Yara         0.820    15
# Luigia       LLM          0.442    15
# Luigia       Yara         0.442    15
# Yara         LLM          0.597    15
#
# Average pairwise alpha per coder:
#   Alexander: 0.706
#   Assia: 0.483
#   Elisa: 0.661
#   Luigia: 0.365
#   Yara: 0.706
#   LLM: 0.560
#
# ✅ Overall Krippendorff's alpha: α = 0.591
# Politicized investigations_present: 5 articles with coder disagreement
# Politicized investigations_present: 10 articles with coder agreement
# Politicized investigations_present: 15 articles coded by all coders
#
# === Frame: Authoritarian reformism_present ===
# Coder A      Coder B      Alpha    Shared Articles
# ---------------------------------------------
# Alexander    Assia        -0.036   15
# Alexander    Elisa        -0.036   15
# Alexander    LLM          1.000    15
# Alexander    Luigia       -0.074   15
# Alexander    Yara         -0.036   15
# Assia        Elisa        -0.115   15
# Assia        LLM          -0.036   15
# Assia        Luigia       0.304    15
# Assia        Yara         0.442    15
# Elisa        LLM          -0.036   15
# Elisa        Luigia       0.768    15
# Elisa        Yara         0.442    15
# Luigia       LLM          -0.074   15
# Luigia       Yara         0.768    15
# Yara         LLM          -0.036   15
#
# Average pairwise alpha per coder:
#   Alexander: 0.164
#   Assia: 0.112
#   Elisa: 0.205
#   Luigia: 0.338
#   Yara: 0.316
#   LLM: 0.164
#
# ✅ Overall Krippendorff's alpha: α = 0.243
# Authoritarian reformism_present: 4 articles with coder disagreement
# Authoritarian reformism_present: 11 articles with coder agreement
# Authoritarian reformism_present: 15 articles coded by all coders
#
# === Frame: Judicial and institutional accountability failures_present ===
# Coder A      Coder B      Alpha    Shared Articles
# ---------------------------------------------
# Alexander    Assia        0.233    15
# Alexander    Elisa        0.861    15
# Alexander    LLM          -0.249   15
# Alexander    Luigia       0.344    15
# Alexander    Yara         0.223    15
# Assia        Elisa        0.130    15
# Assia        LLM          -0.343   15
# Assia        Luigia       0.194    15
# Assia        Yara         0.344    15
# Elisa        LLM          -0.160   15
# Elisa        Luigia       0.223    15
# Elisa        Yara         0.356    15
# Luigia       LLM          0.011    15
# Luigia       Yara         0.344    15
# Yara         LLM          0.099    15
#
# Average pairwise alpha per coder:
#   Alexander: 0.282
#   Assia: 0.112
#   Elisa: 0.282
#   Luigia: 0.223
#   Yara: 0.273
#   LLM: -0.128
#
# ✅ Overall Krippendorff's alpha: α = 0.226
# Judicial and institutional accountability failures_present: 12 articles with coder disagreement
# Judicial and institutional accountability failures_present: 3 articles with coder agreement
# Judicial and institutional accountability failures_present: 15 articles coded by all coders
#
# === Frame: Mobilizing anti-corruption_present ===
# Coder A      Coder B      Alpha    Shared Articles
# ---------------------------------------------
# Alexander    Assia        0.597    15
# Alexander    Elisa        0.460    15
# Alexander    LLM          0.768    15
# Alexander    Luigia       0.460    15
# Alexander    Yara         0.768    15
# Assia        Elisa        0.847    15
# Assia        LLM          0.820    15
# Assia        Luigia       0.847    15
# Assia        Yara         0.820    15
# Elisa        LLM          0.670    15
# Elisa        Luigia       0.710    15
# Elisa        Yara         0.670    15
# Luigia       LLM          0.670    15
# Luigia       Yara         0.670    15
# Yara         LLM          1.000    15
#
# Average pairwise alpha per coder:
#   Alexander: 0.610
#   Assia: 0.786
#   Elisa: 0.671
#   Luigia: 0.671
#   Yara: 0.786
#   LLM: 0.786
#
# ✅ Overall Krippendorff's alpha: α = 0.714
# Mobilizing anti-corruption_present: 4 articles with coder disagreement
# Mobilizing anti-corruption_present: 11 articles with coder agreement
# Mobilizing anti-corruption_present: 15 articles coded by all coders
#
# ✅ Frame-level results saved to 'reliability_results_with_llm.xlsx'
# ✅ Pairwise alpha results saved to 'pairwise_krippendorff_by_frame.xlsx'
# ⚠️ Skipping unknown annotator: Anne
# ⚠️ Skipping unknown annotator: anne
# ⚠️ Skipping unknown annotator: code1
# ⚠️ Skipping unknown annotator: coder1
# ⚠️ Skipping unknown annotator: frozen
# ⚠️ Skipping unknown annotator: simone
# ✅ Annotators who coded all 15 articles: ['Alexander', 'Assia', 'Elisa', 'Luigia', 'Yara']
# ✅ Agreement Excel saved to: /home/akroon/webdav/ASCOR-FMG-5580-RESPOND-news-data (Projectfolder)/annotations/coding_frames/ICR/agreement_with_yara_and_text.xlsx

# %%
import os
import json
import pandas as pd
import numpy as np
import krippendorff
from itertools import combinations
import matplotlib.pyplot as plt
import seaborn as sns
from openpyxl import Workbook
from openpyxl.styles import PatternFill

# === CONFIG ===
SESSION_FOLDER = os.path.expanduser("~/webdav/ASCOR-FMG-5580-RESPOND-news-data (Projectfolder)/sessions/")


LLM_FILE = os.path.expanduser(
    "~/webdav/ASCOR-FMG-5580-RESPOND-news-data (Projectfolder)/annotations/coding_frames/ICR/ICR_test1/news_sample_with_7_frames_intercoder.csv"
)
UPDATED_LLM_FILE = os.path.expanduser(
    "~/webdav/ASCOR-FMG-5580-RESPOND-news-data (Projectfolder)/output/news_sample_with_7_frames_adjusted_prompt.csv"
)

# === FRAME DEFINITIONS ===
FRAME_LABELS = [
    "Foreign influence threat_present",
    "Systemic institutional corruption_present",
    "Elite collusion_present",
    "Politicized investigations_present",
    "Authoritarian reformism_present",
    "Judicial and institutional accountability failures_present",
    "Mobilizing anti-corruption_present"
]

FRAME_NAME_TO_COLUMN = {
    "Foreign influence threat_present": "frame_1_name",
    "Systemic institutional corruption_present": "frame_2_name",
    "Elite collusion_present": "frame_3_name",
    "Politicized investigations_present": "frame_4_name",
    "Authoritarian reformism_present": "frame_5_name",
    "Judicial and institutional accountability failures_present": "frame_6_name",
    "Mobilizing anti-corruption_present": "frame_7_name"
}

# === HELPERS ===
def encode_label(val):
    return 1 if val == "Present" else 0 if val == "Not Present" else None

def load_all_annotations():
    data = []

    # Define allowed coders (case-insensitive)
    allowed_annotators = ["Assia", "Alexander", "Elisa", "Luigia", "Yara"]
    allowed_set = set(a.lower() for a in allowed_annotators)

    for filename in os.listdir(SESSION_FOLDER):
        if filename.endswith("_session.json"):
            user_id = filename.replace("_session.json", "")
            user_id_lower = user_id.lower()

            if user_id_lower not in allowed_set:
                print(f"⚠️ Skipping unknown annotator: {user_id}")
                continue

            path = os.path.join(SESSION_FOLDER, filename)
            with open(path, "r", encoding="utf-8") as f:
                session_data = json.load(f)
                annotations = session_data.get("annotations", [])
                for ann in annotations:
                    ann["user_id"] = user_id
                    data.append(ann)

    df = pd.DataFrame(data)

    # Only keep annotators who coded all 15 articles
    annotator_counts = df.groupby("user_id")["uri"].nunique()
    complete_annotators = annotator_counts[annotator_counts == 15].index.tolist()
    df = df[df["user_id"].isin(complete_annotators)]

    print(f"✅ Annotators who coded all 15 articles: {complete_annotators}")
    return df


def prepare_matrix(df, frame_label):
    df_sub = df[["user_id", "uri", frame_label]].copy()
    df_sub[frame_label] = df_sub[frame_label].map(encode_label)
    pivot = df_sub.pivot(index="uri", columns="user_id", values=frame_label)
    return pivot

# === EXPORT FUNCTION ===
def export_agreement_with_yara_and_text(df, llm_df, updated_llm_df, output_path="agreement_with_yara_and_text.xlsx"):
    wb = Workbook()
    wb.remove(wb.active)

    # Pull translated texts from LLM file
    translated_texts = llm_df.set_index("uri")["translated_text"]

    for frame_label in FRAME_LABELS:
        llm_col = FRAME_NAME_TO_COLUMN[frame_label]

        # Human matrix
        matrix = prepare_matrix(df, frame_label)

        # --- Original LLM ---
        llm_frame = llm_df[["uri", llm_col]].copy()
        llm_frame[llm_col] = llm_frame[llm_col].apply(lambda x: "Present" if isinstance(x, str) and x.strip() else "Not Present")
        llm_frame[llm_col] = llm_frame[llm_col].map(encode_label)
        llm_frame = llm_frame.set_index("uri").rename(columns={llm_col: "LLM"})

        # --- Updated LLM ---
        updated_llm_frame = updated_llm_df[["uri", llm_col]].copy()
        updated_llm_frame[llm_col] = updated_llm_frame[llm_col].apply(lambda x: "Present" if isinstance(x, str) and x.strip() else "Not Present")
        updated_llm_frame[llm_col] = updated_llm_frame[llm_col].map(encode_label)
        updated_llm_frame = updated_llm_frame.set_index("uri").rename(columns={llm_col: "LLM_Updated"})

        # Join all
        combined_matrix = matrix.join(llm_frame).join(updated_llm_frame)

        if "Yara" not in combined_matrix.columns:
            print(f"⚠️ Skipping {frame_label} — Yara missing")
            continue

        combined_matrix["translated_text"] = translated_texts

        # Agreement matrix
        yara_vector = combined_matrix["Yara"]
        agreement_df = combined_matrix.drop(columns=["Yara", "translated_text"]).copy()
        for col in agreement_df.columns:
            agreement_df[col] = agreement_df[col] == yara_vector

        # Write sheet
        ws = wb.create_sheet(title=frame_label[:31])
        ws.append(["URI", "Translated Text"] + list(agreement_df.columns) + ["Yara"])

        green_fill = PatternFill(start_color="C6EFCE", end_color="C6EFCE", fill_type="solid")
        red_fill = PatternFill(start_color="FFC7CE", end_color="FFC7CE", fill_type="solid")

        for uri in combined_matrix.index:
            row = [uri, combined_matrix.loc[uri, "translated_text"]]
            for col in agreement_df.columns:
                row.append(combined_matrix.loc[uri, col])
            row.append(combined_matrix.loc[uri, "Yara"])
            ws.append(row)

        # Apply color
        for i, uri in enumerate(combined_matrix.index, start=2):  # skip header
            for j, col in enumerate(agreement_df.columns, start=3):
                cell = ws.cell(row=i, column=j)
                agrees = agreement_df.loc[uri, col]
                val = combined_matrix.loc[uri, col]
                yara_val = combined_matrix.loc[uri, "Yara"]

                if pd.isna(val) or pd.isna(yara_val):
                    continue
                cell.fill = green_fill if agrees else red_fill

    wb.save(output_path)
    print(f"✅ Agreement Excel saved to: {output_path}")

# === RUN ===
if __name__ == "__main__":
    df = load_all_annotations()
    llm_df = pd.read_csv(LLM_FILE)
    updated_llm_df = pd.read_csv(UPDATED_LLM_FILE)

    llm_df["user_id"] = "LLM"
    updated_llm_df["user_id"] = "LLM_Updated"

    export_agreement_with_yara_and_text(
        df, llm_df, updated_llm_df,
        output_path=os.path.expanduser(
            "~/webdav/ASCOR-FMG-5580-RESPOND-news-data (Projectfolder)/annotations/coding_frames/ICR/agreement_with_yara_and_text.xlsx"
        )
    )
# Out:
# ⚠️ Skipping unknown annotator: Anne
# ⚠️ Skipping unknown annotator: anne
# ⚠️ Skipping unknown annotator: code1
# ⚠️ Skipping unknown annotator: coder1
# ⚠️ Skipping unknown annotator: frozen
# ⚠️ Skipping unknown annotator: simone
# ✅ Annotators who coded all 15 articles: ['Alexander', 'Assia', 'Elisa', 'Luigia', 'Yara']
# ✅ Agreement Excel saved to: /home/akroon/webdav/ASCOR-FMG-5580-RESPOND-news-data (Projectfolder)/annotations/coding_frames/ICR/agreement_with_yara_and_text.xlsx
